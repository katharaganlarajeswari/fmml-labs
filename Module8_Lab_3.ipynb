# %% [markdown]
# <a href="https://colab.research.google.com/github/katharaganlarajeswari/fmml-labs/blob/main/Module8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-04-21 15:36:12--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   170MB/s    in 0.4s
#
# 2025-04-21 15:36:14 (170 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3099    1204.2311v1  Nonnegative Matrix Factorization (NMF) is a wi...    cs
# 12120  1708.08022v1  The recent, remarkable growth of machine learn...  stat
# 14389  cs/0001010v1  In this paper we describe ExtrAns, an answer e...    cs
# 37312  1703.04221v2  Automatic decision-making approaches, such as ...    cs
# 16110  1609.08075v1  Non-linear models recently receive a lot of at...    cs
# ...             ...                                                ...   ...
# 9317    1205.3997v1  The free energy functional has recently been p...  stat
# 21540   0912.3604v2  We provide yet another proof of the existence ...  stat
# 10974   1307.0048v3  In this paper, we propose a one-pass algorithm...  stat
# 9384   1606.07025v1  Attack graphs provide compact representations ...    cs
# 9441   1801.03132v1  In biostatistics, propensity score is a common...  stat
#
#                                                    title  year  \
# 3099   Robust Nonnegative Matrix Factorization via $L...  2012
# 12120  On the Protection of Private Information in Ma...  2017
# 14389   A Real World Implementation of Answer Extraction  2000
# 37312  A Hierarchical Framework of Cloud Resource All...  2017
# 16110  S-MART: Novel Tree-based Structured Learning A...  2016
# ...                                                  ...   ...
# 9317   Free Energy and the Generalized Optimality Equ...  2012
# 21540                   A Geometric Proof of Calibration  2009
# 10974  Simple one-pass algorithm for penalized linear...  2013
# 9384   Efficient Attack Graph Analysis through Approx...  2016
# 9441   Robust Propensity Score Computation Method bas...  2018
#
#                                                 keywords
# 3099   [nonnegative, factorization, technique, applic...
# 12120  [remarkable, techniques, preserving, literatur...
# 14389  [extraction, extraction, retrieving, ambitious...
# 37312  [automatic, approaches, reinforcement, allocat...
# 16110  [attention, statistical, embedding, structured...
# ...                                                  ...
# 9317   [functional, variational, principle, instantia...
# 21540  [existence, calibrated, forecasters, arbitrary...
# 10974  [algorithm, mapreduce, penalized, regression, ...
# 9384   [representations, compromise, resources, analy...
# 9441   [biostatistics, propensity, imbalance, covaria...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3099     [nonnegative, factorization, technique, applic...
# 12120    [remarkable, techniques, preserving, literatur...
# 14389    [extraction, extraction, retrieving, ambitious...
# 37312    [automatic, approaches, reinforcement, allocat...
# 16110    [attention, statistical, embedding, structured...
#                                ...
# 6296     [reparameterization, optimizing, stochastic, c...
# 21920    [multivariate, regression, predictors, differe...
# 10626    [alternating, direction, multipliers, optimiza...
# 9400     [principle, component, naturally, separations,...
# 7096     [comparing, traditional, criterion, nonlinear,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8815 words.
# Out of those 4505 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e8fb6dd0-784a-4ca8-95ef-f09a67b3b5a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8fb6dd0-784a-4ca8-95ef-f09a67b3b5a8")) {                    Plotly.newPlot(                        "e8fb6dd0-784a-4ca8-95ef-f09a67b3b5a8",                        [{"x":["factorization","algorithm","segmentation","justification","partially","particular","corruption","applications","information","experimental","representation","optimization","efficient","requiring","dimensional","positions","iterative","theoretical","demonstrate","corrupted","advantages","estimates","technique","recognition","explicitly","nonnegative","traditional","regularization","approximates","remarkable","principles","preserving","techniques","approaches","schroeder","literature","protection","distilled","highlighting","retrieving","retrieval","presented","implementation","answering","retrieves","extraction","generated","knowledge","sentences","selective","arbitrarily","documents","translated","hierarchical","consumption","computing","furthermore","allocation","predictor","complicated","reliability","dimensions","management","usefulness","autoencoder","reinforcement","degradation","increases","acceptable","comprises","distributed","accelerate","automatic","effective","adaptively","operating","necessary","maintaining","performance","structure","convergence","framework","statistical","attention","especially","regression","structures","inference","embedding","algorithms","classification","functions","component","outperforms","significantly","different","structured","estimation","estimated","identifying","identification","describes","computerized","solutions","integrate","integrated","extensions","boundedness","indefinitely","extension","decidable","situation","maintains","infinitely","quantification","controlled","verification","arbitrary","situations","investigate","eventually","stochastic","suggesting","logarithmic","partition","distributions","polynomial","evaluating","likelihood","clustering","guarantee","guarantees","heterogeneous","progression","bidirectional","understanding","detection","baselines","untrimmed","revealing","performing","categorization","challenging","multithumos","abstractions","interacting","potential","effectiveness","improvements","describing","components","achieving","significant","evaluated","attributes","exploiting","depicting","efficiently","multistage","apparently","influence","previously","evaluation","practical","implemented","difficulties","autonomous","mathematically","challenge","simultaneously","simulated","adversarially","supervise","including","intrinsically","abilities","gathering","extrinsic","generation","intrinsic","motivated","formalize","unstructured","environment","informative","developing","motivation","localization","implements","ecologically","environments","naturalistic","behaviors","prediction","interactions","consequences","experiment","conditioned","architecture","automatically"],"y":[42,840,207,8,38,280,9,377,728,354,353,329,423,41,189,20,77,187,558,18,96,67,217,372,74,11,178,91,11,23,32,52,389,435,1,112,10,0,12,8,97,169,146,62,2,123,154,334,79,17,16,59,15,101,23,131,178,32,22,30,33,54,57,23,22,118,21,54,15,20,128,25,181,232,28,22,82,45,877,347,120,572,161,184,122,140,138,214,107,599,482,218,114,250,263,730,110,198,63,72,87,76,2,150,45,53,37,2,2,76,8,34,13,1,14,33,35,84,53,151,12,123,17,19,28,99,53,46,57,150,35,62,32,8,24,171,342,62,3,12,78,22,267,2,6,17,144,221,103,45,107,70,230,153,54,73,7,163,4,8,63,107,237,140,104,26,60,4,180,121,49,7,5,264,7,13,9,5,133,35,55,12,22,99,40,61,14,59,11,2,86,3,29,248,72,14,93,19,258,177],"type":"bar"},{"x":["factorization","algorithm","segmentation","justification","partially","pa ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4505,), (4505, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8166666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.48235294117647054);'>Development</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Fuzzy</span> <span style=''>Expert</span> <span style=''>System</span> <span style=''>based</span> <span style=''>Liveliness</span> <span style='background-color:rgba(0, 255, 0, 0.5032967032967033);'>Detection</span> <span style=''>Scheme</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Biometric</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777778);'>Authentication</span> <br/><br/><span style=''>Liveliness</span> <span style='background-color:rgba(0, 255, 0, 0.5032967032967033);'>detection</span> <span style=''>acts</span> <span style=''>as</span> <span style=''>a</span> <span style=''>safe</span> <span style=''>guard</span> <span style=''>against</span> <span style=''>spoofing</span> <span style=''>attacks</span> <span style=''>Most</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3962264150943397);'>researchers</span> <span style=''>used</span> <span style=''>vision</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>liveliness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>user</span> <span style=''>but</span> <span style=''>they</span> <span style=''>are</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>illumination</span> <span style=''>effects</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Therefore</span> <span style=''>it</span> <span style=''>is</span> <span style=''>very</span> <span style=''>hard</span> <span style=''>to</span> <span style=''>design</span> <span style=''>a</span> <span style=''>system</span> <span style=''>which</span> <span style=''>will</span> <span style=''>work</span> <span style=''>robustly</span> <span style=''>under</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.4736842105263158);'>circumstances</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Literature</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>most</span> <span style=''>of</span> <span style=''>the</span> <span style=''>research</span> <span style=''>utilize</span> <span style=''>eye</span> <span style=''>blink</span> <span style=''>or</span> <span style=''>mouth</span> <span style=''>movement</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>the</span> <span style=''>liveliness</span> <span style=''>while</span> <span style=''>the</span> <span style=''>other</span> <span style=''>group</span> <span style=''>used</span> <span style=''>face</span> <span style=''>texture</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distinguish</span> <span style=''>between</span> <span style=''>real</span> <span style=''>and</span> <span style=''>imposter</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>results</span> <span style=''>of</span> <span style=''>all</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decreases</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>drastically</span> <span style=''>in</span> <span style=''>variable</span> <span style=''>light</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>Hence</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introducing</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deepr</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style=''>Net</span> <span style=''>for</span> <span style=''>Medical</span> <span style=''>Records</span> <br/><br/><span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>engineering</span> <span style=''>remains</span> <span style=''>a</span> <span style=''>major</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bottleneck</span> <span style=''>when</span> <span style=''>creating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>systems</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>electronic</span> <span style=''>medical</span> <span style=''>records</span> <span style=''>At</span> <span style=''>present</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>missing</span> <span style=''>element</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detecting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>regular</span> <span style=''>clinical</span> <span style=''>motifs</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>irregular</span> <span style=''>episodic</span> <span style=''>records</span> <span style=''>We</span> <span style=''>present</span> <span style=''>Deepr</span> <span style=''>(short</span> <span style=''>for</span> <span style=''>Deep</span> <span style=''>record)</span> <span style=''>a</span> <span style=''>new</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>system</span> <span style=''>that</span> <span style=''>learns</span> <span style=''>to</span> <span style=''>extract</span> <span style=''>features</span> <span style=''>from</span> <span style=''>medical</span> <span style=''>records</span> <span style=''>and</span> <span style=''>predicts</span> <span style=''>future</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style=''>Deepr</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transforms</span> <span style=''>a</span> <span style=''>record</span> <span style=''>into</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>discrete</span> <span style=''>elements</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separated</span> <span style=''>by</span> <span style=''>coded</span> <span style=''>time</span> <span style=''>gaps</span> <span style=''>and</span> <span style=''>hospital</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transfers</span> <span style=''>On</span> <span style=''>top</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>net</span> <span style=''>that</span> <span style=''>detects</span> <span style=''>and</span> <span style=''>combines</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>local</span> <span style=''>clinical</span> <span style=''>motifs</span> <span style=''>to</span> <span style=''>stratify</span> <span style=''>the</span> <span style=''>risk</span> <span style=''>Deepr</span> <span style=''>permits</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transparent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inspection</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>visualization</span> <span style=''>of</span> <span style=''>its</span> <span style=''>inner</span> <span style=''>working</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Inference</span> <span style=''>via</span> <span style=''>Greedy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Importance</span> <span style=''>Sampling</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conducting</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>which</span> <span style=''>combines</span> <span style=''>explicit</span> <span style=''>search</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>sampling</span> <span style=''>The</span> <span style=''>idea</span> <span style=''>is</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>variance</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>sampling</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>searching</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.34502923976608185);'>significant</span> <span style=''>points</span> <span style=''>in</span> <span style=''>the</span> <span style=''>target</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>search</span> <span style=''>and</span> <span style=''>still</span> <span style=''>maintain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unbiasedness</span> <span style=''>We</span> <span style=''>then</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>on</span> <span style=''>a</span> <span style=''>few</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>tasks</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>it</span> <span style=''>can</span> <span style=''>improve</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>standard</span> <span style=''>MCMC</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>Gibbs</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Metropolis</span> <span style=''>sampling</span> <span style=''>and</span> <span style=''>Hybrid</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>extends</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>which</span> <span style=''>showed</span> <span style=''>how</span> <span style=''>greedy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>sampling</span> <span style=''>could</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correctly</span> <span style=''>realized</span> <span style=''>in</span> <span style=''>the</span> <span style=''>one</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Hourly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Similarity</span> <span style=''>Based</span> <span style=''>Solar</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Forecasting</span> <span style=''>Using</span> <span style=''>Multi</span> <span style=''>Model</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>Blending</span> <br/><br/><span style=''>With</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penetration</span> <span style=''>of</span> <span style=''>solar</span> <span style=''>power</span> <span style=''>into</span> <span style=''>power</span> <span style=''>systems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style=''>becomes</span> <span style=''>critical</span> <span style=''>in</span> <span style=''>power</span> <span style=''>system</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operations</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>an</span> <span style=''>hourly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>(HS)</span> <span style=''>based</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>for</span> <span style=''>1</span> <span style=''>hour</span> <span style=''>ahead</span> <span style=''>(1HA)</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>horizontal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>irradiance</span> <span style=''>(GHI)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>method</span> <span style=''>utilizes</span> <span style=''>diurnal</span> <span style=''>patterns</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distinctions</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>hours</span> <span style=''>and</span> <span style=''>hourly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarities</span> <span style=''>in</span> <span style=''>solar</span> <span style=''>data</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style=''>accuracy</span> <span style=''>The</span> <span style=''>HS</span> <span style=''>based</span> <span style=''>method</span> <span style=''>is</span> <span style=''>built</span> <span style=''>by</span> <span style=''>training</span> <span style=''>multiple</span> <span style=''>two</span> <span style=''>layer</span> <span style=''>multi</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>(MMFF)</span> <span style=''>models</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span style=''>with</span> <span style=''>the</span> <span style=''>same</span> <span style=''>hour</span> <span style=''>subsets</span> <span style=''>The</span> <span style=''>final</span> <span style=''>optimal</span> <span style=''>model</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combination</span> <span style=''>of</span> <span style=''>MMFF</span> <span style=''>models</span> <span style=''>with</span> <span style=''>the</span> <span style=''>best</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performed</span> <span style=''>blending</span> <sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.12697274031563846)
# 	representation (0.12661406025824964)
# 	processing (0.10724533715925394)
# 	architecture (0.09253945480631277)
# 	segmentation (0.0742467718794835)
# 	detection (0.12266857962697274)
# 	different (0.2618364418938307)
# 	information (0.2611190817790531)
# 	convolutional (0.13773314203730272)
# 	recognition (0.133428981348637)
#
# Some Statistics words are:
# 	convergence (0.12326043737574553)
# 	stochastic (0.1257455268389662)
# 	variables (0.13916500994035785)
# 	variational (0.10636182902584493)
# 	estimation (0.16848906560636182)
# 	statistical (0.15805168986083498)
# 	distribution (0.1878727634194831)
# 	inference (0.19532803180914513)
# 	regression (0.17395626242544732)
# 	dimensional (0.19582504970178927)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b232581c-ab83-48ad-91c5-4f738bd9cd0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b232581c-ab83-48ad-91c5-4f738bd9cd0d")) {                    Plotly.newPlot(                        "b232581c-ab83-48ad-91c5-4f738bd9cd0d",                        [{"x":["factorization","algorithm","segmentation","justification","partially","particular","corruption","applications","information","experimental","representation","optimization","efficient","requiring","dimensional","positions","iterative","theoretical","demonstrate","corrupted","advantages","estimates","technique","recognition","explicitly","nonnegative","traditional","regularization","approximates","remarkable","principles","preserving","techniques","approaches","schroeder","literature","protection","distilled","highlighting","retrieving","retrieval","presented","implementation","answering","retrieves","extraction","generated","knowledge","sentences","selective","arbitrarily","documents","translated","hierarchical","consumption","computing","furthermore","allocation","predictor","complicated","reliability","dimensions","management","usefulness","autoencoder","reinforcement","degradation","increases","acceptable","comprises","distributed","accelerate","automatic","effective","adaptively","operating","necessary","maintaining","performance","structure","convergence","framework","statistical","attention","especially","regression","structures","inference","embedding","algorithms","classification","functions","component","outperforms","significantly","different","structured","estimation","estimated","identifying","identification","describes","computerized","solutions","integrate","integrated","extensions","boundedness","indefinitely","extension","decidable","situation","maintains","infinitely","quantification","controlled","verification","arbitrary","situations","investigate","eventually","stochastic","suggesting","logarithmic","partition","distributions","polynomial","evaluating","likelihood","clustering","guarantee","guarantees","heterogeneous","progression","bidirectional","understanding","detection","baselines","untrimmed","revealing","performing","categorization","challenging","multithumos","abstractions","interacting","potential","effectiveness","improvements","describing","components","achieving","significant","evaluated","attributes","exploiting","depicting","efficiently","multistage","apparently","influence","previously","evaluation","practical","implemented","difficulties","autonomous","mathematically","challenge","simultaneously","simulated","adversarially","supervise","including","intrinsically","abilities","gathering","extrinsic","generation","intrinsic","motivated","formalize","unstructured","environment","informative","developing","motivation","localization","implements","ecologically","environments","naturalistic","behaviors","prediction","interactions","consequences","experiment","conditioned","architecture","automatically","adversarial","generative","annotated","introduce","realistic","infrastructure","generating","direction","dependency","collaboratively","synthetic","preferences","demanding","suggested","improvement","strategies","preference","cognitive","involving","combinatorial","constrained","scenarios","constructive","decomposition","configurations","implications","constraints","variables","elicitation","synthesized","exclusively","empirical","promising","computationally","additionally","configuration","interaction","drastically","advantage","reconstruction","extensively","movielens","interpolate","regularizers","conservative","interpolation","generalizing","formulation","parameters","correctly","parameter","uncertainty","embeddings","processes","convo ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	distilled
# 	straggler
# 	stragglers
# 	straggling
# 	rescaling
# 	factorizes
# 	rightarrow
# 	pharmacokinetic
# 	cognitively
# 	parametrically
# 	commonplace
# 	tolerates
# 	pessimistic
# 	invariably
# 	conformalized
# 	elucidate
# 	unverifiable
# 	econometrics
# 	itinerary
# 	conjugacy
# Some words which never appear in Statistics papers:
# 	retrieves
# 	computerized
# 	indefinitely
# 	decidable
# 	untrimmed
# 	multithumos
# 	depicting
# 	multistage
# 	supervise
# 	ecologically
# 	digitization
# 	undertaking
# 	codebooks
# 	uncontrolled
# 	enumerate
# 	institute
# 	operative
# 	reservoirs
# 	suppressed
# 	alphabets

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.087849312953528e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.77
